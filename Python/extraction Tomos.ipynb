# %%
import numpy as np
import pandas as pd

# Replace 'your_excel_file.xlsx' with the actual path to your Excel file

year =2010
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2022/bericht/Financial-statements-2021.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2021/bericht/Financial-statements-2020.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2020/gb/Financial-statements%202019.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2019/gb/BMW-AG-Financial-statement-2018.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2018/gb/Financial_statement_2017.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2017/GB/Financial_statement.xlsx'
excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2015/Consolidated_Financial_Statement_BMW_Group_FY-2015_EN.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2015/evpr/analyst---investor/2014-FY-BMW-Group-Financial-Statement-Spreadsheet.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2014/events---presentations/annual-account/2013-BMW-Group-Financial-Statement-Spreadsheet.xls'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2013/events_und_praesentationen/analyst_and_investor_conference/2012-BMW-Group-Financial-Statement-Spreadsheet.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2012/events_and_presentations/annual_accounts/2012-BMW-Group-Financial-Statement-Spreadsheet.xlsx'
#excel_file_path = 'https://www.bmwgroup.com/content/dam/grpw/websites/bmwgroup_com/ir/downloads/en/2011/events_and_presentations/annual_accounts/2010-BMW-Group-Financial-Statement-Spreadsheet.xls'

# Read Excel file into a Pandas DataFrame
df = pd.read_excel(excel_file_path)

# Display the DataFrame
df.head(15)
# Out:
# C:\Users\tomos\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#                                             BMW GROUP Unnamed: 1 Unnamed: 2  \
# 0   Income Statement for Group and Segments for th...        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN      Group        NaN
# 3                                                 NaN        NaN        NaN
# 4                                        in € million       2015       2014
# 5                                                 NaN        NaN        NaN
# 6                                                 NaN        NaN        NaN
# 7                                            Revenues     92.175     80.401
# 8                                       Cost of sales    -74.043    -63.396
# ...

# %%
#Remove first three lines
#Before 2016
#df = df.drop([0,1,2])
#After 2016
df = df.drop([0,1,2,3,4,5,6])

# Take away odd columns with spaces (nans)
#df = df.drop(columns=df.columns[1::2])
df.set_index(df.columns[0], inplace=True)
df = df.dropna(how='all')
df = df.dropna(axis=1,how='all')

# %%
df.head()
# Out:
#                                     Unnamed: 1 Unnamed: 2 Unnamed: 4  \
# BMW GROUP
# Revenues                                92.175     80.401     85.536
# Cost of sales                          -74.043    -63.396    -70.399
# Gross profit                            18.132     17.005     15.137
# Selling and administrative expenses     -8.633     -7.892     -7.219
# Other operating income                     914        877        689
#
#                                      Unnamed: 5 Unnamed: 7 Unnamed: 8  \
# BMW GROUP
# Revenues                                 75.173       1.99      1.679
# Cost of sales                           -61.221     -1.542     -1.365
# Gross profit                             13.952        448        314
# Selling and administrative expenses      -6.645       -239       -201
# Other operating income                  749.000          -          -
#
#                                     Unnamed: 10 Unnamed: 11 Unnamed: 13  \
# BMW GROUP
# ...

# %%
#Transpose
df = df.T

# %%
df.head()
# Out:
# BMW Group  Revenues Cost of sales Gross profit Sales and administrative costs  \
# Unnamed: 1    68821        -54276        14545                          -6177
# Unnamed: 2    60477        -49545        10932                          -5529
# Unnamed: 4    63229        -50164        13065                          -5260
# Unnamed: 5    54137        -44703         9434                          -4778
# Unnamed: 7     1436         -1207          229                           -176
#
# BMW Group  Other operating income Other operating expenses  \
# Unnamed: 1                    782                    -1132
# Unnamed: 2                    766                    -1058
# Unnamed: 4                    528                     -856
# Unnamed: 5                    508                     -809
# Unnamed: 7                      2                      -10
#
# BMW Group  Profit / loss before financial result  \
# Unnamed: 1                                  8018
# ...

# %%
#df_timeseries = pd.DataFrame(df.iloc[0]).T

# Set the index of 'df_timeseries' to 2021
#df_timeseries.index = [2021]

#df_timeseries.head()
#df_timeseries.to_csv('df_timeseries.csv')

# %%
#df_timeseries = pd.read_csv('df_timeseries.csv')
df_timeseries.loc[year] = df.iloc[0]
df_timeseries.head(20)
# Out:
# BMW GROUP Revenues Cost of sales Gross profit  \
# 2021        111239        -89253        21986
# 2020         98990        -85408        13582
# 2019        104210        -86147        18063
# 2018         97480        -78924        18556
# 2017         98678        -78744        19934
# 2016         94163        -75442        18721
# 2015        92.175       -74.043       18.132
# 2014         80401        -63396        17005
# 2013         76058        -60784        15274
# 2012         76848        -61354        15494
# 2011         68821        -54276        14545
#
# BMW GROUP Selling and administrative expenses Other operating income  \
# 2021                                    -9233                   1702
# 2020                                    -8795                    916
# 2019                                    -9367                   1031
# 2018                                    -9558                    774
# ...

# %%
df_timeseries['Revenues'].plot()
# Out:
# <Axes: >

# %%
df_timeseries.loc[2015] = df_timeseries.loc[2015]*1000

# %%
df_timeseries.to_csv('./df_timeseries.csv')
